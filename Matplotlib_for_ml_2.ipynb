# %%
import matplotlib.pyplot as plt

# %%
classes = ['Python', 'R', 'ML', 'AI', 'DS']
class1_students = [45, 15, 35, 25, 30]

# %%
plt.pie(class1_students, labels = classes)
plt.show()

# %%
'''
plt.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1,
        startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False,
        rotatelabels=False, *, normalize=None, data=None)
'''

plt.pie(class1_students, labels = classes, explode = [0.1,0,0,0,0])
plt.show()

# %%
plt.pie(class1_students, labels = classes, explode = [0.1,0,0,0,0], autopct = "%0.2f%%")
plt.show()

# %%
plt.pie(class1_students, labels = classes, explode = [0.1,0,0,0,0], autopct = "%0.2f%%", shadow = True)
plt.show()

# %%
plt.pie(class1_students, labels = classes, explode = [0.1,0,0,0,0], autopct = "%0.2f%%", shadow = True, radius = 1.5)
plt.show()

# %%
plt.pie(class1_students, labels = classes, explode = [0.1,0,0,0,0], autopct = "%0.2f%%", shadow = True, radius = 1.5,
       startangle = 90)
plt.show()

# %%
plt.pie(class1_students, labels = classes, explode = [0.1,0,0,0,0], autopct = "%0.2f%%", shadow = True, radius = 1.5,
       startangle = 90, textprops = {"fontsize":15})
plt.show()

# %%
plt.pie(class1_students, labels = classes, explode = [0.1,0,0,0,0], autopct = "%0.2f%%", shadow = True, radius = 1.5,
       startangle = 90, textprops = {"fontsize":15}, wedgeprops = {'linewidth': 4})
plt.show()

# %%
plt.pie(class1_students, labels = classes, explode = [0.1,0,0,0,0], autopct = "%0.2f%%", shadow = True, radius = 1.5,
       startangle = 90, textprops = {"fontsize":15}, wedgeprops = {'linewidth': 2, 'width': 1, 'edgecolor': 'k'})
plt.show()

# %%
plt.pie(class1_students, labels = classes, explode = [0.1,0,0,0,0], autopct = "%0.2f%%", shadow = True, radius = 1.5,
       startangle = 90, textprops = {"fontsize":15}, wedgeprops = {'linewidth': 2, 'width': 1, 'edgecolor': 'k'})

plt.legend(title = 'Courses:', loc = 'center')
plt.show()
